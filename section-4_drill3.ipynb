# %% [markdown]
# # Coding drill 3

# %%
from sklearn.datasets import load_wine

import pandas as pd  # fill in with the proper package name 
import numpy as np

# %%
# Converts the load_wine() data from array to dataframe
def get_wine_data():
    data = load_wine() # contains data (the features and labels), the names for the columns
    features = data.data # equivalent to data["data"] (data is a dictionary)
    labels = data.target
    df = pd.DataFrame(features) # making a dataframe from a 2d array
    df.columns = data.feature_names # setting the names of the columns
    df["labels"] = labels
    return df

# %%
# Get the names of the columns
def get_feature_titles():
    df = get_wine_data()
    return df.columns

# %%
get_feature_titles()
# Out:
# Index(['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'magnesium',
#        'total_phenols', 'flavanoids', 'nonflavanoid_phenols',
#        'proanthocyanins', 'color_intensity', 'hue',
#        'od280/od315_of_diluted_wines', 'proline', 'labels'],
#       dtype='object')

# %%
def add_2_to_magnesium():
    df = get_wine_data()
    df['magnesium'] += 2
    return df

add_2_to_magnesium()
# Out:
#      alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0      14.23        1.71  2.43               15.6      129.0           2.80
# 1      13.20        1.78  2.14               11.2      102.0           2.65
# 2      13.16        2.36  2.67               18.6      103.0           2.80
# 3      14.37        1.95  2.50               16.8      115.0           3.85
# 4      13.24        2.59  2.87               21.0      120.0           2.80
# ..       ...         ...   ...                ...        ...            ...
# 173    13.71        5.65  2.45               20.5       97.0           1.68
# 174    13.40        3.91  2.48               23.0      104.0           1.80
# 175    13.27        4.28  2.26               20.0      122.0           1.59
# 176    13.17        2.59  2.37               20.0      122.0           1.65
# 177    14.13        4.10  2.74               24.5       98.0           2.05
#
# ...

# %%
def create_flav_to_non_flav_ratio():
    df = get_wine_data()
    df["flav_to_non_flav_ratio"] = df["flavanoids"] / df["nonflavanoid_phenols"]
    return df.head()

df_head = create_flav_to_non_flav_ratio()
df_head
# Out:
#    alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0    14.23        1.71  2.43               15.6      127.0           2.80
# 1    13.20        1.78  2.14               11.2      100.0           2.65
# 2    13.16        2.36  2.67               18.6      101.0           2.80
# 3    14.37        1.95  2.50               16.8      113.0           3.85
# 4    13.24        2.59  2.87               21.0      118.0           2.80
#
#    flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# 1        2.76                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
# 3        3.49                  0.24             2.18             7.80  0.86
# 4        2.69                  0.39             1.82             4.32  1.04
#
# ...

# %%
def get_num_missing_values():
    df = get_wine_data()
    return df.isna().sum()

# %%
get_num_missing_values()
# Out:
# alcohol                         0
# malic_acid                      0
# ash                             0
# alcalinity_of_ash               0
# magnesium                       0
# total_phenols                   0
# flavanoids                      0
# nonflavanoid_phenols            0
# proanthocyanins                 0
# color_intensity                 0
# hue                             0
# od280/od315_of_diluted_wines    0
# proline                         0
# labels                          0
# dtype: int64

# %%
def alcohol_content_level_sifter():
    df = get_wine_data()
    data_num = len(df.index)
    df["alcohol_content_level"] = 0
    for i in range(data_num):
        if df.loc[i, "alcohol"] >= 13.5:
            df.loc[i, "alcohol_content_level"] = 1
    return df

def alcohol_content_level_sifter2():
    df = get_wine_data()
    df1 = df[df["alcohol"] >= 13.5].copy()
    df2 = df[df["alcohol"] < 13.5].copy()
    df1["alcohol_content_level"] = 1
    df2["alcohol_content_level"] = 0
    df = pd.concat([df1, df2])
    df.sort_index(inplace=True)
    return df

# %%
df = get_wine_data()
len(df.index)
# Out:
# 178

# %%
df = get_wine_data()
data_num = len(df.index)
df["alcohol_content_level"] = 0
df
# Out:
#      alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0      14.23        1.71  2.43               15.6      127.0           2.80
# 1      13.20        1.78  2.14               11.2      100.0           2.65
# 2      13.16        2.36  2.67               18.6      101.0           2.80
# 3      14.37        1.95  2.50               16.8      113.0           3.85
# 4      13.24        2.59  2.87               21.0      118.0           2.80
# ..       ...         ...   ...                ...        ...            ...
# 173    13.71        5.65  2.45               20.5       95.0           1.68
# 174    13.40        3.91  2.48               23.0      102.0           1.80
# 175    13.27        4.28  2.26               20.0      120.0           1.59
# 176    13.17        2.59  2.37               20.0      120.0           1.65
# 177    14.13        4.10  2.74               24.5       96.0           2.05
#
# ...

# %%
alcohol_content_level_sifter()
# Out:
#      alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0      14.23        1.71  2.43               15.6      127.0           2.80
# 1      13.20        1.78  2.14               11.2      100.0           2.65
# 2      13.16        2.36  2.67               18.6      101.0           2.80
# 3      14.37        1.95  2.50               16.8      113.0           3.85
# 4      13.24        2.59  2.87               21.0      118.0           2.80
# ..       ...         ...   ...                ...        ...            ...
# 173    13.71        5.65  2.45               20.5       95.0           1.68
# 174    13.40        3.91  2.48               23.0      102.0           1.80
# 175    13.27        4.28  2.26               20.0      120.0           1.59
# 176    13.17        2.59  2.37               20.0      120.0           1.65
# 177    14.13        4.10  2.74               24.5       96.0           2.05
#
# ...

# %%
df
# Out:
#      alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0      14.23        1.71  2.43               15.6      127.0           2.80
# 1      13.20        1.78  2.14               11.2      100.0           2.65
# 2      13.16        2.36  2.67               18.6      101.0           2.80
# 3      14.37        1.95  2.50               16.8      113.0           3.85
# 4      13.24        2.59  2.87               21.0      118.0           2.80
# ..       ...         ...   ...                ...        ...            ...
# 173    13.71        5.65  2.45               20.5       95.0           1.68
# 174    13.40        3.91  2.48               23.0      102.0           1.80
# 175    13.27        4.28  2.26               20.0      120.0           1.59
# 176    13.17        2.59  2.37               20.0      120.0           1.65
# 177    14.13        4.10  2.74               24.5       96.0           2.05
#
# ...

# %% [markdown]
# # Assignment 4 - Written response for drill 3

# %% [markdown]
# 1. Why is data preprocessing important?
# Missing values. irrelevant features, non-standardized columns, etc., which could impact computational overhead. Too many features might not be feasible due to computational overhead. Dimensionality reduction techniques often used to drop the features of a dataset.
#
# 2. Benefits/drawbacks of having many features
# Benefits: more comprehensive view on data; more paths to make sense of the data
# Drawbacks: computational overhead, complications in modeling possible
#
# 3. Drop features that have too many missing values. Drop features with a small standard deviation compared to other features (after standardizing all features for fair comparison between features)

# %%
get_wine_data()
# Out:
#      alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0      14.23        1.71  2.43               15.6      127.0           2.80
# 1      13.20        1.78  2.14               11.2      100.0           2.65
# 2      13.16        2.36  2.67               18.6      101.0           2.80
# 3      14.37        1.95  2.50               16.8      113.0           3.85
# 4      13.24        2.59  2.87               21.0      118.0           2.80
# ..       ...         ...   ...                ...        ...            ...
# 173    13.71        5.65  2.45               20.5       95.0           1.68
# 174    13.40        3.91  2.48               23.0      102.0           1.80
# 175    13.27        4.28  2.26               20.0      120.0           1.59
# 176    13.17        2.59  2.37               20.0      120.0           1.65
# 177    14.13        4.10  2.74               24.5       96.0           2.05
#
# ...
